# %% [markdown]
# # [0] 재귀 함수 (Recursive Function)
# - 자기 자신을 다시 호출하는 함수
# - 아래와 같이 반복되는 함수, 단 깊이 제한이 존재함
# - 스택구조와 같이 계속 쌓이는 방식으로 이해할 수 있음
#
# <br/>
#
# - 재귀 함수를 문제 풀이에서 사용할 때는 재귀 함수의 종료 조건을 반드시 명시해야함
# - 종료 조건을 제대로 명시하지 않으면 함수가 무한히 호출되게 됨

# %%
def recursive_function():
    print('재귀 함수를 호출합니다.')
    recursive_function()

recursive_function()
# Out:
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# 재귀 함수를 호출합니다.
# ...

# %% [markdown]
# - 아래 함수는 스택의 자료구조형과 유사하다고 생각할 수 있음

# %%
def recursive_function(i):

    if i == 100:
        return
    print(i, '번째에서', i+1, '번째 재귀함수를 호출합니다.')
    recursive_function(i+1)
    print(i,'번째재귀 함수를 종료합니다.')

recursive_function(1)
# Out:
# 1 번째에서 2 번째 재귀함수를 호출합니다.
# 2 번째에서 3 번째 재귀함수를 호출합니다.
# 3 번째에서 4 번째 재귀함수를 호출합니다.
# 4 번째에서 5 번째 재귀함수를 호출합니다.
# 5 번째에서 6 번째 재귀함수를 호출합니다.
# 6 번째에서 7 번째 재귀함수를 호출합니다.
# 7 번째에서 8 번째 재귀함수를 호출합니다.
# 8 번째에서 9 번째 재귀함수를 호출합니다.
# 9 번째에서 10 번째 재귀함수를 호출합니다.
# 10 번째에서 11 번째 재귀함수를 호출합니다.
# 11 번째에서 12 번째 재귀함수를 호출합니다.
# 12 번째에서 13 번째 재귀함수를 호출합니다.
# 13 번째에서 14 번째 재귀함수를 호출합니다.
# 14 번째에서 15 번째 재귀함수를 호출합니다.
# 15 번째에서 16 번째 재귀함수를 호출합니다.
# 16 번째에서 17 번째 재귀함수를 호출합니다.
# 17 번째에서 18 번째 재귀함수를 호출합니다.
# 18 번째에서 19 번째 재귀함수를 호출합니다.
# 19 번째에서 20 번째 재귀함수를 호출합니다.
# 20 번째에서 21 번째 재귀함수를 호출합니다.
# 21 번째에서 22 번째 재귀함수를 호출합니다.
# 22 번째에서 23 번째 재귀함수를 호출합니다.
# 23 번째에서 24 번째 재귀함수를 호출합니다.
# 24 번째에서 25 번째 재귀함수를 호출합니다.
# 25 번째에서 26 번째 재귀함수를 호출합니다.
# 26 번째에서 27 번째 재귀함수를 호출합니다.
# 27 번째에서 28 번째 재귀함수를 호출합니다.
# 28 번째에서 29 번째 재귀함수를 호출합니다.
# 29 번째에서 30 번째 재귀함수를 호출합니다.
# 30 번째에서 31 번째 재귀함수를 호출합니다.
# 31 번째에서 32 번째 재귀함수를 호출합니다.
# 32 번째에서 33 번째 재귀함수를 호출합니다.
# 33 번째에서 34 번째 재귀함수를 호출합니다.
# 34 번째에서 35 번째 재귀함수를 호출합니다.
# 35 번째에서 36 번째 재귀함수를 호출합니다.
# ...

# %% [markdown]
# ## [0-1] 재귀함수 예시 - 팩토리얼 구현
#
# - 반복문이 사용되지 않고, 간결하게 구현이 가능한 부분이 있다.

# %%
def factorial_recursive(n):
    if n <= 1 :
        return 1
    return n * factorial_recursive(n-1)

print(factorial_recursive(10))
# Out:
# 3628800

# %% [markdown]
# ## [0-2] 유클리드 호제법(최대공약수 계산)
# - 두 개의 자연수에 대한 최대공약수 도출
# - 두 자연수 A,B에 대하여 (A>B) A를 B로 나눈 나머지가 R일때, A와 B의 최대공약수는 B와 R의 최대공약수와 같음

# %%
def gcv(a,b) :
    if a % b == 0:
        return b
    else :
        return gcv(b, a % b)

print(gcv(192,162))
# Out:
# 6

# %% [markdown]
# - 재귀 함수를 잘 활용하면 복잡한 알고리즘을 간결하게 작성할 수 있음
# - 모든 재귀함수는 반복문을 이용하여 동일한 기능을 구현할 수 있음
# - DFS에서는 재귀함수를 이해할 필요가 있음!

# %% [markdown]
# # [1] DFS (Depth First Search)
#
# - DFS는 깊이 우선 탐색이라도 부르며 그래프에서 깊은 부분을 우선적으로 탐색하는 알고리즘
# - DFS는 스택 자료구조(혹은 재귀 함수)를 이용하며, 구체적인 동작 과정은 다음과 같음
# - 보통 번호가 낮은 인접 노드부터 조건을 주는 경우가 많음
#
# - 1. 탐색 시작 노드를 스택에 삽입하고 방문 처리
# - 2. 스택의 최상단 노드에 방문하지 않은 인접한 노드가 하나라도 있으면 그 노드를 스택에 넣고 방문 처리. 방문하지 않은 인접노드가 없으면 스택에서 최상단 노드를 꺼냄
# - 3. 더 이상 2번의 과정을 수행할 수 없을 때까지 반복

# %% [markdown]
# ## [1-1] 예제

# %%
def dfs(graph, v, visited) :
    # 현재 노드를 방문 처리
    visited[v] = True
    print(v, end = ' ')
    # 현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

# 각 노드가 연결된 정보를 표현(2차원 리스트)
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,3,6],
    [1,7]
]

# 각 노드가 방문된 정보를 표현 (1차원 리스트)
visited = [False] * 9

dfs(graph, 1, visited)
# Out:
# 1 2 7 3 4 5 6 8

# %% [markdown]
# # [2] DFS 문제풀이

# %% [markdown]
# ## [2-1] 점프왕 쩰리 (Small)
#
# - 문제
# <br/>
#
# ‘쩰리’는 점프하는 것을 좋아하는 젤리다. 단순히 점프하는 것에 지루함을 느낀 ‘쩰리’는 새로운 점프 게임을 해보고 싶어 한다. 새로운 점프 게임의 조건은 다음과 같다.
#
# ‘쩰리’는 가로와 세로의 칸 수가 같은 정사각형의 구역 내부에서만 움직일 수 있다. ‘쩰리’가 정사각형 구역의 외부로 나가는 경우엔 바닥으로 떨어져 즉시 게임에서 패배하게 된다.
# ‘쩰리’의 출발점은 항상 정사각형의 가장 왼쪽, 가장 위의 칸이다. 다른 출발점에서는 출발하지 않는다.
# ‘쩰리’가 이동 가능한 방향은 오른쪽과 아래 뿐이다. 위쪽과 왼쪽으로는 이동할 수 없다.
# ‘쩰리’가 가장 오른쪽, 가장 아래 칸에 도달하는 순간, 그 즉시 ‘쩰리’의 승리로 게임은 종료된다.
# ‘쩰리’가 한 번에 이동할 수 있는 칸의 수는, 현재 밟고 있는 칸에 쓰여 있는 수 만큼이다. 칸에 쓰여 있는 수 초과나 그 미만으로 이동할 수 없다.
# 새로운 게임이 맘에 든 ‘쩰리’는, 계속 게임을 진행해 마침내 최종 단계에 도달했다. 하지만, 게임을 진행하는 구역이 너무 넓어져버린 나머지, 이 게임에서 이길 수 있는지 없는지 가늠할 수 없어졌다. ‘쩰리’는 유능한 프로그래머인 당신에게 주어진 구역에서 승리할 수 있는 지 알아봐 달라고 부탁했다. ‘쩰리’를 도와 주어진 게임 구역에서 끝 점(오른쪽 맨 아래 칸)까지 도달할 수 있는지를 알아보자!
#
#
# <br/>
#
# - 입력
# <br/>
#
# 입력의 첫 번째 줄에는 게임 구역의 크기 N (2 ≤ N ≤ 3)이 주어진다.
#
# 입력의 두 번째 줄부터 마지막 줄까지 게임판의 구역(맵)이 주어진다.
#
# 게임판의 승리 지점(오른쪽 맨 아래 칸)에는 -1이 쓰여있고, 나머지 칸에는 0 이상 100 이하의 정수가 쓰여있다.
# ```
# 3
# 1 1 10
# 1 5 1
# 2 2 -1
# ```
#
#
# - 출력
# <br/>
#
# ‘쩰리’가 끝 점에 도달할 수 있으면 “HaruHaru”(인용부호 없이), 도달할 수 없으면 “Hing” (인용부호 없이)을 한 줄에 출력합니다.
#
# ```
# HaruHaru
#
# ```

# %% [markdown]
# ## 내 풀이

# %% [markdown]
# ## 풀이과정

# %% [markdown]
# [ [       ]
# [      ]
# [      ] ]
#
# 오른쪽으로 우선 고 (인덱스 더해가면서)
# 만약 주어진 값을 더한게 범위를 벗어나면? 아래로 이동
# 만약 아래로 이동했는데 범위를 벗어나면?

# %%
a = [['a','b'],['c','d']]
a[0][0]
# Out:
# 'a'

# %%
visited = list([False]) * (game_area)
[visited]
# Out:
# [[False, False, False]]

# %%
game_area = int(input())
game_list = []
for _ in range(game_area):
    game_list.append(list(map(int,input().split(' '))))
visited = [[False] * game_area for _ in range(game_area)]

def dfs(x,y):
    if x >= game_area or y >= game_area:
        return False
    game = game_list[x][y]
    if game == -1:
        print('HaruHaru')
        return

    if not visited[x][y]:
        visited[x][y] = 1
        dfs(x + game, y)
        dfs(x, y + game)

dfs(0, 0)
print('Hing')
# 오답
# Out:
# 3
# 2 2 1
# 2 2 2
# 1 2 -1
# Hing

# %%
game_area = int(input())
game_list = []
for _ in range(game_area):
    game_list.append(list(map(int,input().split(' '))))
visited = [[False] * game_area for _ in range(game_area)]

def dfs(x,y):
    if x >= game_area or y >= game_area:
        return False
    game = game_list[x][y]
    if game == -1:
        print('HaruHaru')+
        exit(0)

    if not visited[x][y]:
        visited[x][y] = 1
        dfs(x + game, y)
        dfs(x, y + game)

dfs(0, 0)
print('Hing')

# %% [markdown]
# ## 다른 풀이

# %% [markdown]
# ## [2-2] 바이러스
#
# - 문제
# <br/>
#
# 신종 바이러스인 웜 바이러스는 네트워크를 통해 전파된다. 한 컴퓨터가 웜 바이러스에 걸리면 그 컴퓨터와 네트워크 상에서 연결되어 있는 모든 컴퓨터는 웜 바이러스에 걸리게 된다.
#
# 예를 들어 7대의 컴퓨터가 <그림 1>과 같이 네트워크 상에서 연결되어 있다고 하자. 1번 컴퓨터가 웜 바이러스에 걸리면 웜 바이러스는 2번과 5번 컴퓨터를 거쳐 3번과 6번 컴퓨터까지 전파되어 2, 3, 5, 6 네 대의 컴퓨터는 웜 바이러스에 걸리게 된다. 하지만 4번과 7번 컴퓨터는 1번 컴퓨터와 네트워크상에서 연결되어 있지 않기 때문에 영향을 받지 않는다.
#
#
#
# 어느 날 1번 컴퓨터가 웜 바이러스에 걸렸다. 컴퓨터의 수와 네트워크 상에서 서로 연결되어 있는 정보가 주어질 때, 1번 컴퓨터를 통해 웜 바이러스에 걸리게 되는 컴퓨터의 수를 출력하는 프로그램을 작성하시오.
#
#
# - 입력
# <br/>
# 첫째 줄에는 컴퓨터의 수가 주어진다. 컴퓨터의 수는 100 이하인 양의 정수이고 각 컴퓨터에는 1번 부터 차례대로 번호가 매겨진다. 둘째 줄에는 네트워크 상에서 직접 연결되어 있는 컴퓨터 쌍의 수가 주어진다. 이어서 그 수만큼 한 줄에 한 쌍씩 네트워크 상에서 직접 연결되어 있는 컴퓨터의 번호 쌍이 주어진다.
#
# ```
# 7
# 6
# 1 2
# 2 3
# 1 5
# 5 2
# 5 6
# 4 7
# ```
#
# - 출력
# <br/>
# 1번 컴퓨터가 웜 바이러스에 걸렸을 때, 1번 컴퓨터를 통해 웜 바이러스에 걸리게 되는 컴퓨터의 수를 첫째 줄에 출력한다.
#
# ```
# 4
# ```

# %% [markdown]
# ### 내 풀이

# %%
# 정답
#import sys
#input = sys.stdin.readline

# n,m,r 입력
num = int(input())
pairs = int(input())

# 각 정점들의 인접한 정점을 모아놓을 2차원 배열을 생성
graph = [[] for _ in range(num+1)]

# m개의 그래프 정보를 입력받아 현재 비어있는 인접 리스트에 저장
for _ in range(pairs):
    left, right = map(int, input().split())
	# 해당 문제는 양방향 그래프이므로 두 점 모두 각각의 인접 리스트에 서로를 추가
    graph[left].append(right)
    graph[right].append(left)

visited = [False] * (num+1)

#print(graph)

def dfs(graph, v, visited) :
    #현재 노드를 방문 처리
    visited[v] = True
    #현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

dfs(graph, 1, visited)
print(sum(visited)-1)

# %% [markdown]
# ### 풀이 과정

# %%
def dfs(graph, v, visited) :
    # 현재 노드를 방문 처리
    visited[v] = True
    #print(v, end = ' ')
    # 현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

# 각 노드가 연결된 정보를 표현(2차원 리스트)
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,3,6],
    [1,7],
    [10],
    [9]
]

# 각 노드가 방문된 정보를 표현 (1차원 리스트)
visited = [False] * 11

dfs(graph, 1, visited)

sum(visited)
# Out:
# 8

# %%
list(map(int,['1','2']))
# Out:
# [1, 2]

# %%
tmp = [[]*9]
tmp
# Out:
# [[]]

# %%
tmp = []
a = [['1','2'], ['2','3'],['1','5'], ['5','2'], ['5','6'], ['4','7']]
for i in range(len(a)) :
    if '1' in set(map(int,a[i])):
        tmp[i] =
# Out:
# True

# %%
tmp = []
for i in range(len(a)) :
    if i+1 in a[i] :
        a[i] = a[i].remove(i+1)
        tmp.append(a[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-afd7cf3403b2> in <cell line: 2>()
#       1 tmp = []
#       2 for i in range(len(a)) :
# ----> 3     if i+1 in a[i] :
#       4         a[i] = a[i].remove(i+1)
#       5         tmp.append(a[i])
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
tmp = []
a = [[1,2], [2,3],[1,5], [5,2], [5,6], [4,7]]

for j in range(6) :
    for i in range(len(a)) :
        if j+1 in a[i] :
            a[i] = a[i].remove(j+1)
            tmp.append(a[i])
        else :
            tmp.append(1000)

print(tmp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-b79011f67d9b> in <cell line: 4>()
#       4 for j in range(6) :
#       5     for i in range(len(a)) :
# ----> 6         if j+1 in a[i] :
#       7             a[i] = a[i].remove(j+1)
#       8             tmp.append(a[i])
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
import sys
input = sys.stdin.readline

# n,m,r 입력
num = 7 #map(int, input())
pairs = 6 #map(int, input())

# 각 정점들의 인접한 정점을 모아놓을 2차원 배열을 생성
graph = [[] for _ in range(num+1)]

# m개의 간선의 정보를 입력받아 인접 리스트에 저장
for _ in range(pairs):
		left,right = map(int, input().split())

		# 해당 문제는 양방향 그래프이므로 두 점 모두 각각의 인접 리스트에 서로를 추가
		graph[left].append(right)
		graph[right].append(left)

visited = [False] * (num+1)

def dfs(graph, v, visited) :
    # 현재 노드를 방문 처리
    visited[v] = True
    #print(v, end = ' ')
    # 현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

dfs(graph, 1, visited)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-efa53cb11151> in <cell line: 12>()
#      11 # m개의 간선의 정보를 입력받아 인접 리스트에 저장
#      12 for _ in range(pairs):
# ---> 13                 left,right = map(int, input().split())
#      14
#      15                 # 해당 문제는 양방향 그래프이므로 두 점 모두 각각의 인접 리스트에 서로를 추가
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
# m개의 간선의 정보를 입력받아 인접 리스트에 저장
for _ in range(m):
		s,e = map(int, input().split())

		# 해당 문제는 양방향 그래프이므로 두 점 모두 각각의 인접 리스트에 서로를 추가
		graph[s].append(e)
		graph[e].append(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-e9169121abf2> in <cell line: 5>()
#       3
#       4 # n,m,r 입력
# ----> 5 n,m,r = map(int, input().split())
#       6
#       7
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
import sys
input = sys.stdin.readline

# n,m,r 입력
num = map(int, input())
pairs = map(int, input())

# 각 정점들의 인접한 정점을 모아놓을 2차원 배열을 생성
graph = [[] for _ in range(num+1)]

# m개의 그래프 정보를 입력받아 현재 비어있는 인접 리스트에 저장
for _ in range(pairs):
    left, right = map(int, input().split())
	# 해당 문제는 양방향 그래프이므로 두 점 모두 각각의 인접 리스트에 서로를 추가
    graph[left].append(right)
    graph[right].append(left)

visited = [False] * (num+1)

#print(graph)

def dfs(graph, v, visited) :
    #현재 노드를 방문 처리
    visited[v] = True
    #현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

dfs(graph, 1, visited)
print(sum(visited)-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-72e4b1c197d9> in <cell line: 9>()
#       7
#       8 # 각 정점들의 인접한 정점을 모아놓을 2차원 배열을 생성
# ----> 9 graph = [[] for _ in range(num+1)]
#      10
#      11 # m개의 그래프 정보를 입력받아 현재 비어있는 인접 리스트에 저장
#
# TypeError: unsupported operand type(s) for +: 'map' and 'int'

# %%
# 정답
#import sys
#input = sys.stdin.readline

# n,m,r 입력
num = int(input())
pairs = int(input())

# 각 정점들의 인접한 정점을 모아놓을 2차원 배열을 생성
graph = [[] for _ in range(num+1)]

# m개의 그래프 정보를 입력받아 현재 비어있는 인접 리스트에 저장
for _ in range(pairs):
    left, right = map(int, input().split())
	# 해당 문제는 양방향 그래프이므로 두 점 모두 각각의 인접 리스트에 서로를 추가
    graph[left].append(right)
    graph[right].append(left)

visited = [False] * (num+1)

#print(graph)

def dfs(graph, v, visited) :
    #현재 노드를 방문 처리
    visited[v] = True
    #현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

dfs(graph, 1, visited)
print(sum(visited)-1)

# %% [markdown]
# ### 다른 풀이

# %% [markdown]
# # [3] BFS (Breadth-Frist Search)
#
# - BFS는 너비 우선 탐색으로 가까운 노드부터 우선적으로 탐색하는 알고리즘
# - 큐 자료구조를 보통 이용하며 구체적인 동작 과정은 다음과 같음
#
# - 1) 탐색 시작 노드를 큐에 삽입하고 방문 처리
# - 2) 큐에서 노드를 꺼낸 뒤에 해당 노드의 인접 노드 중에서 방문하지 않은 노드를 모두 큐에 삽입하고 방문 처리
# - 3) 더 이상 2번 과정을 수행할 수 없을 때까지 반복
#
#
# * DFS는 1~8번 값이 있으면 각 값을 순서대로 방문했지만, BFS는 거리 우선 탐색으로 가까운 값들 중 빠른 값들부터 방문하는 특징이 있는듯

# %%
from collections import deque

def bfs(graph, start, visited) :
    # 큐(Queue) 구현을 위해 deque 라이브러리 사용
    queue = deque([start])
    # 현재 노드를 방문 처리
    visited[start] = True
    # 큐가 빌 때까지 반복

    while queue: # 큐가 없을때 까지 계속 수행
        # 큐에서 하나의 원소를 뽑아 출력하기
        v = queue.popleft()
        print(v, end = ' ')
        # 아직 방문하지 않은 인접한 원소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True

# 각 노드가 연결된 정보를 표현(2차원 리스트)
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]

# 각 노드가 방문된 정보를 표현 (1차원 리스트)
visited = [False] * 9

bfs(graph, 1, visited)
# Out:
# 1 2 3 8 7 4 5 6
